# %% [markdown]
# <a href="https://colab.research.google.com/github/manisha-mishra-123/Scaler-projects/blob/main/ScalerMart_Business_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem Statement:
# ScalerMart, a leading global electronics retailer, has experienced a significant downturn in sales, with a nearly 50% decline in revenue in 2020 compared to the previous year.
#
# In response to this challenge, the company is actively seeking a sharp Data Analyst to join their growing team.
#
# You have been assigned the task of analyzing the customer-level transactional data to identify potential reasons behind the decline in sales.
#
# Your objective is to recommend data-driven strategies aimed at improving sales performance.

# %%
# !gdown 1qPrP3QNWjxA_JHwao44dhVapEtQtlfus
# !gdown 1fGc33yN_yTLI-1erTwo4-KdxFMcXDjJD
# !gdown 1S0hQDcTlY3ZUpyD1gf50Cujfs8UTSgnt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qPrP3QNWjxA_JHwao44dhVapEtQtlfus
# To: /content/Customers.csv
# 100% 1.43M/1.43M [00:00<00:00, 76.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fGc33yN_yTLI-1erTwo4-KdxFMcXDjJD
# To: /content/Products.csv
# 100% 305k/305k [00:00<00:00, 83.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1S0hQDcTlY3ZUpyD1gf50Cujfs8UTSgnt
# To: /content/Sales.csv
# 100% 2.80M/2.80M [00:00<00:00, 97.6MB/s]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_cus= pd.read_csv('Customers.csv', encoding='latin1')
df_cus
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df_prod= pd.read_csv('Products.csv')
df_prod
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
df_sales= pd.read_csv('Sales.csv')
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %% [markdown]
# Customers Table Details

# %%
print('\nLength:\n ',len(df_cus))
print('\nSize:\n',df_cus.size)
print('\nShape:\n ',df_cus.shape)
print('\nData types:\n ',df_cus.dtypes)
print('\nDescription: \n',df_cus.describe())
print('\nUnique Values: \n')
for i in df_cus.columns:
  print(i,': ',df_cus[i].nunique())
# Out:
# Length:
#   15266
#
# Size:
#  152660
#
# Shape:
#   (15266, 10)
#
# Data types:
#   CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object
#
# Description:
#          CustomerKey
# count  1.526600e+04
# mean   1.060508e+06
# std    6.127097e+05
# min    3.010000e+02
# 25%    5.140335e+05
# 50%    1.079244e+06
# 75%    1.593980e+06
# max    2.099937e+06
#
# Unique Values:
#
# CustomerKey :  15266
# Gender :  2
# Name :  15118
# City :  8258
# State Code :  467
# State :  512
# Zip Code :  9505
# Country :  8
# Continent :  3
# Birthday :  11270

# %% [markdown]
# Product Table details

# %%
print('Length: ', len(df_prod))
print('\nShape: ', df_prod.shape)
print('\nSize: ', df_prod.size)
print('\nData types:\n ', df_prod.dtypes)
print('\nDescription:\n ', df_prod.describe())
print('\nUnique Values: \n')
for i in df_prod.columns:
  print(i,': ',df_prod[i].nunique())
# Out:
# Length:  2517
#
# Shape:  (2517, 10)
#
# Size:  25170
#
# Data types:
#   ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object
#
# Description:
#           ProductKey  SubcategoryKey  CategoryKey
# count  2517.000000     2517.000000  2517.000000
# mean   1259.000000      491.810091     4.878824
# std     726.739637      229.887134     2.299170
# min       1.000000      101.000000     1.000000
# 25%     630.000000      305.000000     3.000000
# 50%    1259.000000      406.000000     4.000000
# 75%    1888.000000      801.000000     8.000000
# max    2517.000000      808.000000     8.000000
#
# Unique Values:
#
# ProductKey :  2517
# Product Name :  2517
# Brand :  11
# Color :  16
# Unit Cost USD :  480
# Unit Price USD :  426
# SubcategoryKey :  32
# ...

# %% [markdown]
# Sales Table Details

# %%
print('Length: ', len(df_sales))
print('\nShape: ', df_sales.shape)
print('\nSize: ', df_sales.size)
print('\nData types:\n ',df_sales.dtypes)
print('\nDescription:\n ', df_sales.describe())
print('\nUnique Values: \n')
for i in df_sales.columns:
  print(i,': ',df_sales[i].nunique())
# Out:
# Length:  62884
#
# Shape:  (62884, 9)
#
# Size:  565956
#
# Data types:
#   Order Number      int64
# Line Item         int64
# Order Date       object
# Delivery Date    object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object
#
# Description:
#          Order Number     Line Item   CustomerKey      StoreKey    ProductKey  \
# count  6.288400e+04  62884.000000  6.288400e+04  62884.000000  62884.000000
# mean   1.430905e+06      2.164207  1.180797e+06     31.802144   1125.859344
# std    4.532963e+05      1.365170  5.859634e+05     22.978188    709.244010
# min    3.660000e+05      1.000000  3.010000e+02      0.000000      1.000000
# 25%    1.121017e+06      1.000000  6.808580e+05      8.000000    437.000000
# 50%    1.498016e+06      2.000000  1.261200e+06     37.000000   1358.000000
# 75%    1.788010e+06      3.000000  1.686496e+06     53.000000   1650.000000
# ...

# %%
for i in df_cus.columns:
  print(df_cus[i].value_counts())
  print('\n')
# Out:
# CustomerKey
# 301        1
# 1428088    1
# 1425887    1
# 1426096    1
# 1426124    1
#           ..
# 696791     1
# 696874     1
# 696937     1
# 696960     1
# 2099937    1
# Name: count, Length: 15266, dtype: int64
#
#
# Gender
# Male      7748
# Female    7518
# Name: count, dtype: int64
#
#
# Name
# John Smith           4
# Robert Wilson        3
# John Miller          3
# Richard Smith        3
# Mary Davis           3
#                     ..
# Arnaud Fluet         1
# Paulette Chastain    1
# Aceline Moïse        1
# Constance Jobin      1
# Zygmunt Kaminski     1
# Name: count, Length: 15118, dtype: int64
#
#
# City
# Toronto              204
# New York             130
# Los Angeles          119
# Montreal              97
# Chicago               92
#                     ...
# Ronneburg              1
# Gangkofen              1
# Heßheim                1
# Bremen Kattenesch      1
# Lorton                 1
# Name: count, Length: 8258, dtype: int64
#
#
# State Code
# ...

# %%
print('\nNull values Customer Table: \n',df_cus.isnull().sum())
# Out:
# Null values Customer Table:
#  CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
df_cus.loc[df_cus['State Code'].isnull(), ['State', 'State Code']]
# Out:
#        State State Code
# 5304  Napoli        NaN
# 5316  Napoli        NaN
# 5372  Napoli        NaN
# 5377  Napoli        NaN
# 5378  Napoli        NaN
# 5485  Napoli        NaN
# 5525  Napoli        NaN
# 5531  Napoli        NaN
# 5631  Napoli        NaN
# 5695  Napoli        NaN

# %%
df_cus['State Code'].fillna('NA', inplace= True)

# %%
for i in df_prod.columns:
  print(df_prod[i].value_counts(),'\n')
# Out:
# ProductKey
# 1       1
# 1683    1
# 1676    1
# 1677    1
# 1678    1
#        ..
# 840     1
# 841     1
# 842     1
# 843     1
# 2517    1
# Name: count, Length: 2517, dtype: int64
#
# Product Name
# Contoso 512MB MP3 Player E51 Silver                                       1
# MGS Hand Games for 12-16 boys E600 Silver                                 1
# MGS Hand Games women M400 Red                                             1
# MGS Hand Games for 12-16 boys E600 Red                                    1
# MGS Hand Games for Office worker L299 Red                                 1
#                                                                          ..
# Contoso Laptop Cooling Hub notebook fan with 4 ports USB hub M200 Gold    1
# Contoso Reserve Pen - Tablet Pen E200 Gold                                1
# Contoso Bright Light battery E20 Black                                    1
# Contoso Bright Light battery E20 blue                                     1
# ...

# %%
print('\nNull values Prod Table:\n', df_prod.isnull().sum())
# Out:
# Null values Prod Table:
#  ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
for i in df_sales.columns:
  print(df_sales[i].value_counts(),'\n')
# Out:
# Order Number
# 1025000    7
# 1529001    7
# 1529028    7
# 1220005    7
# 1422011    7
#           ..
# 1469018    1
# 786002     1
# 1761001    1
# 786001     1
# 366000     1
# Name: count, Length: 26326, dtype: int64
#
# Line Item
# 1    26326
# 2    16789
# 3    10248
# 4     5125
# 5     2175
# 6     1476
# 7      745
# Name: count, dtype: int64
#
# Order Date
# 12/21/2019    222
# 1/4/2020      219
# 12/28/2019    215
# 12/29/2018    206
# 2/22/2020     204
#              ...
# 6/11/2017       1
# 7/8/2018        1
# 3/17/2019       1
# 8/19/2018       1
# 10/16/2016      1
# Name: count, Length: 1641, dtype: int64
#
# Delivery Date
# 1/6/2020      50
# 1/7/2019      44
# 12/25/2019    43
# 2/24/2019     41
# 1/5/2020      41
#               ..
# 10/27/2020     1
# 5/17/2017      1
# 10/29/2020     1
# 5/9/2017       1
# 8/25/2020      1
# Name: count, Length: 1492, dtype: int64
#
# CustomerKey
# 723572     36
# 1579183    32
# 1925694    32
# 1942072    29
# 1972249    29
# ...

# %%
print('\nNull values Sales Table:\n', df_sales.isnull().sum())
# Out:
# Null values Sales Table:
#  Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
df_sales.groupby('Order Number').filter(lambda x: len(x) > 1)
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# 5            366002          3   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62877       2243029          5  2/20/2021     2/27/2021       887764
# 62878       2243029          6  2/20/2021     2/27/2021       887764
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 1             0        1048         2           USD
# ...

# %%
df_sales=df_sales[~df_sales.duplicated()]
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales.fillna('Unknown', inplace=True)
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016       Unknown       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021       Unknown      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# Delivery Date    0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
merged_df=pd.merge(df_cus,df_sales,on='CustomerKey', how='left')
merged_df.astype('int64')
# Out:
#        CustomerKey  Gender              Name                 City State Code  \
# 0              301  Female     Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female      Madison Hull           MOUNT BUDD         WA
# 2              325  Female      Madison Hull           MOUNT BUDD         WA
# 3              325  Female      Madison Hull           MOUNT BUDD         WA
# 4              325  Female      Madison Hull           MOUNT BUDD         WA
# ...            ...     ...               ...                  ...        ...
# 66258      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 66259      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 66260      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 66261      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
# 66262      2099937    Male  Zygmunt Kaminski  Bloomfield Township         MI
#
# ...
